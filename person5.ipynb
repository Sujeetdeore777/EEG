# %%
import numpy as np
import mne
from mne.decoding import CSP
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import confusion_matrix, accuracy_score, cohen_kappa_score
import matplotlib.pyplot as plt
import seaborn as sns


# Function to preprocess data and extract specific events
def preprocess_data(file_path, event_ids):
    raw = mne.io.read_raw_gdf(file_path, preload=True)
    raw.set_eeg_reference()

    # Select EEG channels and create epochs
    desired_channels = ['EEG:C3', 'EEG:Cz', 'EEG:C4']
    raw.pick_channels(desired_channels)
    events, _ = mne.events_from_annotations(raw)
    epochs = mne.Epochs(raw, events, event_id=event_ids, on_missing='warn')
    labels = epochs.events[:, -1]
    data = epochs.get_data()

    return data, labels

# File paths and corresponding event IDs
file_paths = ["Person5\B0501T.gdf", "Person5\B0502T.gdf"]
event_ids_list = [{'T0': 10, 'T1': 11}, {'T0': 10, 'T1': 11}]

# Lists to store preprocessed data and labels
all_data = []
all_labels = []

# Preprocess data from each file and extract specific events
for file_path, event_ids in zip(file_paths, event_ids_list):
    data, labels = preprocess_data(file_path, event_ids)
    all_data.append(data)
    all_labels.append(labels)

# Concatenate the data and labels arrays from all files
merged_data = np.concatenate(all_data, axis=0)
merged_labels = np.concatenate(all_labels, axis=0)

# Parameters
n_channels = merged_data.shape[1]
window_size = 200
step_size = 5

# Frequency bands
frequency_bands = [(2, 6), (6, 10), (10, 14), (14, 18),
                   (18, 22), (22, 26), (26, 30), (30, 34)]

# Extract CSP features for each frequency band
X_band = []  # List to store features
y_band = []  # List to store labels

for band_idx, (fmin, fmax) in enumerate(frequency_bands):
    for t_start in range(0, merged_data.shape[0] - window_size + 1, step_size):
        t_end = t_start + window_size
        X_window = merged_data[:, :, t_start:t_end]
        y_window = merged_labels

        csp = CSP(n_components=10, transform_into='average_power')
        csp.fit(X_window, y_window)
        X_band.append(csp.transform(X_window))
        y_band.extend(y_window)

# Convert lists to numpy arrays
X_band = np.concatenate(X_band, axis=0)
y_band = np.array(y_band)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_band, y_band, test_size=0.4, random_state=42)

input_shape = (3,1)

model = keras.Sequential()
model.add(layers.Reshape((3, 1), input_shape=input_shape))  # Reshape the input to (3, 1) for 1D convolution
model.add(layers.Conv1D(16, kernel_size=3, activation='relu', padding='same'))
model.add(layers.MaxPooling1D(pool_size=2))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(4, activation='softmax'))  # Adjust units to match the number of classes

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

y_train_processed = y_train - 10  # Map 10 to 0 and 11 to 1
y_test_processed = y_test - 10

history = model.fit(X_train, y_train_processed, epochs=250, batch_size=32, validation_split=0.1)

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test_processed)

# Predict labels for the test set
predicted_labels = model.predict(X_test)
predicted_labels = np.argmax(predicted_labels, axis=1)

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test_processed, predicted_labels)

# Calculate overall accuracy
accuracy = accuracy_score(y_test_processed, predicted_labels)

# Calculate Cohen's Kappa score
kappa = cohen_kappa_score(y_test_processed, predicted_labels)

# Print accuracy and kappa score
print(f"Test accuracy: {accuracy}")
print(f"Cohen's Kappa score: {kappa}")

# Plot confusion matrix
plt.figure(figsize=(5, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Left ', 'Right'], yticklabels=['Left', 'Right'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# Extracting EDF parameters from c:\Users\HP\Desktop\session2\Person5\B0501T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_14284\3253647731.py:14: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path, preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Used Annotations descriptions: ['1023', '1077', '1078', '1079', '1081', '276', '277', '32766', '768', '769', '770']
# Not setting metadata
# 120 matching events found
# Setting baseline interval to [-0.2, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 120 events and 176 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from c:\Users\HP\Desktop\session2\Person5\B0502T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 696265  =      0.000 ...  2785.060 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_14284\3253647731.py:14: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path, preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Used Annotations descriptions: ['1023', '1077', '1078', '1079', '1081', '276', '277', '32766', '768', '769', '770']
# Not setting metadata
# 140 matching events found
# Setting baseline interval to [-0.2, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 140 events and 176 original time points ...
# 0 bad epochs dropped
# Computing rank from data with rank=None
#     Using tolerance 6.4e-07 (2.2e-16 eps * 3 dim * 9.6e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.3e-07 (2.2e-16 eps * 3 dim * 9.5e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.2e-07 (2.2e-16 eps * 3 dim * 9.4e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.2e-07 (2.2e-16 eps * 3 dim * 9.3e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.1e-07 (2.2e-16 eps * 3 dim * 9.2e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6e-07 (2.2e-16 eps * 3 dim * 9.1e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6e-07 (2.2e-16 eps * 3 dim * 9e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.9e-07 (2.2e-16 eps * 3 dim * 8.9e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.8e-07 (2.2e-16 eps * 3 dim * 8.8e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.8e-07 (2.2e-16 eps * 3 dim * 8.6e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.7e-07 (2.2e-16 eps * 3 dim * 8.5e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.6e-07 (2.2e-16 eps * 3 dim * 8.4e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.5e-07 (2.2e-16 eps * 3 dim * 8.3e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.3e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.4e-07 (2.2e-16 eps * 3 dim * 9.6e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.3e-07 (2.2e-16 eps * 3 dim * 9.5e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.2e-07 (2.2e-16 eps * 3 dim * 9.4e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.2e-07 (2.2e-16 eps * 3 dim * 9.3e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.1e-07 (2.2e-16 eps * 3 dim * 9.2e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6e-07 (2.2e-16 eps * 3 dim * 9.1e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6e-07 (2.2e-16 eps * 3 dim * 9e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.9e-07 (2.2e-16 eps * 3 dim * 8.9e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.8e-07 (2.2e-16 eps * 3 dim * 8.8e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.8e-07 (2.2e-16 eps * 3 dim * 8.6e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.7e-07 (2.2e-16 eps * 3 dim * 8.5e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.6e-07 (2.2e-16 eps * 3 dim * 8.4e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.5e-07 (2.2e-16 eps * 3 dim * 8.3e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.3e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.4e-07 (2.2e-16 eps * 3 dim * 9.6e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.3e-07 (2.2e-16 eps * 3 dim * 9.5e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.2e-07 (2.2e-16 eps * 3 dim * 9.4e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.2e-07 (2.2e-16 eps * 3 dim * 9.3e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.1e-07 (2.2e-16 eps * 3 dim * 9.2e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6e-07 (2.2e-16 eps * 3 dim * 9.1e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6e-07 (2.2e-16 eps * 3 dim * 9e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.9e-07 (2.2e-16 eps * 3 dim * 8.9e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.8e-07 (2.2e-16 eps * 3 dim * 8.8e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.8e-07 (2.2e-16 eps * 3 dim * 8.6e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.7e-07 (2.2e-16 eps * 3 dim * 8.5e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.6e-07 (2.2e-16 eps * 3 dim * 8.4e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.5e-07 (2.2e-16 eps * 3 dim * 8.3e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.3e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.4e-07 (2.2e-16 eps * 3 dim * 9.6e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.3e-07 (2.2e-16 eps * 3 dim * 9.5e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.2e-07 (2.2e-16 eps * 3 dim * 9.4e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.2e-07 (2.2e-16 eps * 3 dim * 9.3e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.1e-07 (2.2e-16 eps * 3 dim * 9.2e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6e-07 (2.2e-16 eps * 3 dim * 9.1e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6e-07 (2.2e-16 eps * 3 dim * 9e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.9e-07 (2.2e-16 eps * 3 dim * 8.9e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.8e-07 (2.2e-16 eps * 3 dim * 8.8e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.8e-07 (2.2e-16 eps * 3 dim * 8.6e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.7e-07 (2.2e-16 eps * 3 dim * 8.5e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.6e-07 (2.2e-16 eps * 3 dim * 8.4e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.5e-07 (2.2e-16 eps * 3 dim * 8.3e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.3e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.4e-07 (2.2e-16 eps * 3 dim * 9.6e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.3e-07 (2.2e-16 eps * 3 dim * 9.5e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.2e-07 (2.2e-16 eps * 3 dim * 9.4e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.2e-07 (2.2e-16 eps * 3 dim * 9.3e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.1e-07 (2.2e-16 eps * 3 dim * 9.2e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6e-07 (2.2e-16 eps * 3 dim * 9.1e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6e-07 (2.2e-16 eps * 3 dim * 9e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.9e-07 (2.2e-16 eps * 3 dim * 8.9e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.8e-07 (2.2e-16 eps * 3 dim * 8.8e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.8e-07 (2.2e-16 eps * 3 dim * 8.6e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.7e-07 (2.2e-16 eps * 3 dim * 8.5e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.6e-07 (2.2e-16 eps * 3 dim * 8.4e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.5e-07 (2.2e-16 eps * 3 dim * 8.3e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.3e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.4e-07 (2.2e-16 eps * 3 dim * 9.6e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.3e-07 (2.2e-16 eps * 3 dim * 9.5e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.2e-07 (2.2e-16 eps * 3 dim * 9.4e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.2e-07 (2.2e-16 eps * 3 dim * 9.3e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.1e-07 (2.2e-16 eps * 3 dim * 9.2e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6e-07 (2.2e-16 eps * 3 dim * 9.1e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6e-07 (2.2e-16 eps * 3 dim * 9e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.9e-07 (2.2e-16 eps * 3 dim * 8.9e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.8e-07 (2.2e-16 eps * 3 dim * 8.8e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.8e-07 (2.2e-16 eps * 3 dim * 8.6e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.7e-07 (2.2e-16 eps * 3 dim * 8.5e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.6e-07 (2.2e-16 eps * 3 dim * 8.4e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.5e-07 (2.2e-16 eps * 3 dim * 8.3e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.3e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.4e-07 (2.2e-16 eps * 3 dim * 9.6e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-06 (2.2e-16 eps * 3 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.3e-07 (2.2e-16 eps * 3 dim * 9.5e+08  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
# ...
# Epoch 143/250
# 457/457 [==============================] - 2s 3ms/step - loss: 0.4681 - accuracy: 0.7565 - val_loss: 0.4742 - val_accuracy: 0.7572
# Epoch 144/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4664 - accuracy: 0.7565 - val_loss: 0.4636 - val_accuracy: 0.7616
# Epoch 145/250
# 457/457 [==============================] - 2s 3ms/step - loss: 0.4661 - accuracy: 0.7572 - val_loss: 0.4682 - val_accuracy: 0.7597
# Epoch 146/250
# 457/457 [==============================] - 1s 3ms/step - loss: 0.4647 - accuracy: 0.7618 - val_loss: 0.4640 - val_accuracy: 0.7597
# Epoch 147/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4653 - accuracy: 0.7611 - val_loss: 0.4709 - val_accuracy: 0.7548
# Epoch 148/250
# 457/457 [==============================] - 1s 3ms/step - loss: 0.4649 - accuracy: 0.7592 - val_loss: 0.4606 - val_accuracy: 0.7505
# Epoch 149/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4639 - accuracy: 0.7610 - val_loss: 0.4723 - val_accuracy: 0.7455
# Epoch 150/250
# 457/457 [==============================] - 2s 3ms/step - loss: 0.4629 - accuracy: 0.7570 - val_loss: 0.4620 - val_accuracy: 0.7529
# Epoch 151/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4625 - accuracy: 0.7601 - val_loss: 0.4765 - val_accuracy: 0.7412
# Epoch 152/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4626 - accuracy: 0.7599 - val_loss: 0.4777 - val_accuracy: 0.7455
# Epoch 153/250
# 457/457 [==============================] - 1s 3ms/step - loss: 0.4631 - accuracy: 0.7591 - val_loss: 0.4725 - val_accuracy: 0.7566
# Epoch 154/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4608 - accuracy: 0.7592 - val_loss: 0.4604 - val_accuracy: 0.7548
# Epoch 155/250
# 457/457 [==============================] - 2s 3ms/step - loss: 0.4594 - accuracy: 0.7623 - val_loss: 0.4683 - val_accuracy: 0.7437
# Epoch 156/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.
250
# 457/457 [==============================] - 2s 3ms/step - loss: 0.4235 - accuracy: 0.7814 - val_loss: 0.4320 - val_accuracy: 0.7646
# Epoch 222/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4185 - accuracy: 0.7888 - val_loss: 0.4316 - val_accuracy: 0.7628
# Epoch 223/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4189 - accuracy: 0.7870 - val_loss: 0.4207 - val_accuracy: 0.7733
# Epoch 224/250
# 457/457 [==============================] - 1s 3ms/step - loss: 0.4207 - accuracy: 0.7853 - val_loss: 0.4127 - val_accuracy: 0.7874
# Epoch 225/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4234 - accuracy: 0.7821 - val_loss: 0.4110 - val_accuracy: 0.7819
# Epoch 226/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4195 - accuracy: 0.7858 - val_loss: 0.4348 - val_accuracy: 0.7689
# Epoch 227/250
# 457/457 [==============================] - 2s 3ms/step - loss: 0.4187 - accuracy: 0.7878 - val_loss: 0.4161 - val_accuracy: 0.7763
# Epoch 228/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4163 - accuracy: 0.7924 - val_loss: 0.4145 - val_accuracy: 0.7862
# Epoch 229/250
# 457/457 [==============================] - 2s 3ms/step - loss: 0.4155 - accuracy: 0.7876 - val_loss: 0.4235 - val_accuracy: 0.7794
# Epoch 230/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4174 - accuracy: 0.7878 - val_loss: 0.4247 - val_accuracy: 0.7745
# Epoch 231/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4165 - accuracy: 0.7893 - val_loss: 0.4104 - val_accuracy: 0.7880
# Epoch 232/250
# 457/457 [==============================] - 2s 3ms/step - loss: 0.4172 - accuracy: 0.7881 - val_loss: 0.4160 - val_accuracy: 0.7856
# Epoch 233/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4179 - accuracy: 0.7886 - val_loss: 0.4325 - val_accuracy: 0.7794
# Epoch 234/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4206 - accuracy: 0.7862 - val_loss: 0.4172 - val_accuracy: 0.7868
# Epoch 235/250
# 457/457 [==============================] - 2s 3ms/step - loss: 0.4145 - accuracy: 0.7899 - val_loss: 0.4176 - val_accuracy: 0.7757
# Epoch 236/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4174 - accuracy: 0.7862 - val_loss: 0.4088 - val_accuracy: 0.7930
# Epoch 237/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4174 - accuracy: 0.7876 - val_loss: 0.4046 - val_accuracy: 0.7905
# Epoch 238/250
# 457/457 [==============================] - 1s 3ms/step - loss: 0.4133 - accuracy: 0.7891 - val_loss: 0.4127 - val_accuracy: 0.7751
# Epoch 239/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4144 - accuracy: 0.7882 - val_loss: 0.4133 - val_accuracy: 0.7708
# Epoch 240/250
# 457/457 [==============================] - 1s 3ms/step - loss: 0.4148 - accuracy: 0.7861 - val_loss: 0.4102 - val_accuracy: 0.7905
# Epoch 241/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4130 - accuracy: 0.7878 - val_loss: 0.4086 - val_accuracy: 0.7887
# Epoch 242/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4124 - accuracy: 0.7906 - val_loss: 0.4245 - val_accuracy: 0.7696
# Epoch 243/250
# 457/457 [==============================] - 2s 3ms/step - loss: 0.4160 - accuracy: 0.7834 - val_loss: 0.4257 - val_accuracy: 0.7634
# Epoch 244/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4111 - accuracy: 0.7928 - val_loss: 0.4181 - val_accuracy: 0.7794
# Epoch 245/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4116 - accuracy: 0.7917 - val_loss: 0.4172 - val_accuracy: 0.7843
# Epoch 246/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4146 - accuracy: 0.7885 - val_loss: 0.4076 - val_accuracy: 0.7880
# Epoch 247/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4136 - accuracy: 0.7874 - val_loss: 0.3993 - val_accuracy: 0.7917
# Epoch 248/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4122 - accuracy: 0.7890 - val_loss: 0.4132 - val_accuracy: 0.7887
# Epoch 249/250
# 457/457 [==============================] - 2s 3ms/step - loss: 0.4108 - accuracy: 0.7917 - val_loss: 0.4102 - val_accuracy: 0.7850
# Epoch 250/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4096 - accuracy: 0.7906 - val_loss: 0.4084 - val_accuracy: 0.7782
# 338/338 [==============================] - 1s 2ms/step - loss: 0.4239 - accuracy: 0.7805
# 338/338 [==============================] - 1s 2ms/step
# Test accuracy: 0.7805103550295858
# Cohen's Kappa score: 0.5611803546926586
