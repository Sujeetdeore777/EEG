# %%
import numpy as np
import mne
from mne.decoding import CSP
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import confusion_matrix, accuracy_score, cohen_kappa_score
import matplotlib.pyplot as plt
import seaborn as sns


# Function to preprocess data and extract specific events
def preprocess_data(file_path, event_ids):
    raw = mne.io.read_raw_gdf(file_path, preload=True)
    raw.set_eeg_reference()

    # Select EEG channels and create epochs
    desired_channels = ['EEG:C3', 'EEG:Cz', 'EEG:C4']
    raw.pick_channels(desired_channels)
    events, _ = mne.events_from_annotations(raw)
    epochs = mne.Epochs(raw, events, event_id=event_ids, on_missing='warn')
    labels = epochs.events[:, -1]
    data = epochs.get_data()

    return data, labels

# File paths and corresponding event IDs
file_paths = ["Person3\B0301T.gdf", "Person3\B0302T.gdf"]
event_ids_list = [{'T0': 10, 'T1': 11}, {'T0': 10, 'T1': 11}]

# Lists to store preprocessed data and labels
all_data = []
all_labels = []

# Preprocess data from each file and extract specific events
for file_path, event_ids in zip(file_paths, event_ids_list):
    data, labels = preprocess_data(file_path, event_ids)
    all_data.append(data)
    all_labels.append(labels)

# Concatenate the data and labels arrays from all files
merged_data = np.concatenate(all_data, axis=0)
merged_labels = np.concatenate(all_labels, axis=0)

# Parameters
n_channels = merged_data.shape[1]
window_size = 200
step_size = 5

# Frequency bands
frequency_bands = [(2, 6), (6, 10), (10, 14), (14, 18),
                   (18, 22), (22, 26), (26, 30), (30, 34)]

# Extract CSP features for each frequency band
X_band = []  # List to store features
y_band = []  # List to store labels

for band_idx, (fmin, fmax) in enumerate(frequency_bands):
    for t_start in range(0, merged_data.shape[0] - window_size + 1, step_size):
        t_end = t_start + window_size
        X_window = merged_data[:, :, t_start:t_end]
        y_window = merged_labels

        csp = CSP(n_components=5, transform_into='average_power')
        csp.fit(X_window, y_window)
        X_band.append(csp.transform(X_window))
        y_band.extend(y_window)

# Convert lists to numpy arrays
X_band = np.concatenate(X_band, axis=0)
y_band = np.array(y_band)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_band, y_band, test_size=0.3, random_state=42)

input_shape = (3,1)

model = keras.Sequential()
model.add(layers.Reshape((3, 1), input_shape=input_shape))  # Reshape the input to (3, 1) for 1D convolution
model.add(layers.Conv1D(16, kernel_size=3, activation='relu', padding='same'))
model.add(layers.MaxPooling1D(pool_size=2))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(4, activation='softmax'))  # Adjust units to match the number of classes

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

y_train_processed = y_train - 10  # Map 10 to 0 and 11 to 1
y_test_processed = y_test - 10

history = model.fit(X_train, y_train_processed, epochs=50, batch_size=32, validation_split=0.1)

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test_processed)

# Predict labels for the test set
predicted_labels = model.predict(X_test)
predicted_labels = np.argmax(predicted_labels, axis=1)

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test_processed, predicted_labels)

# Calculate overall accuracy
accuracy = accuracy_score(y_test_processed, predicted_labels)

# Calculate Cohen's Kappa score
kappa = cohen_kappa_score(y_test_processed, predicted_labels)

# Print accuracy and kappa score
print(f"Test accuracy: {accuracy}")
print(f"Cohen's Kappa score: {kappa}")

# Plot confusion matrix
plt.figure(figsize=(5, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Left ', 'Right'], yticklabels=['Left', 'Right'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# Extracting EDF parameters from c:\Users\HP\Desktop\session2\Person3\B0301T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_9708\3243634268.py:14: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path, preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Used Annotations descriptions: ['1023', '1077', '1078', '1079', '1081', '276', '277', '32766', '768', '769', '770']
# Not setting metadata
# 120 matching events found
# Setting baseline interval to [-0.2, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 120 events and 176 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from c:\Users\HP\Desktop\session2\Person3\B0302T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_9708\3243634268.py:14: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path, preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Used Annotations descriptions: ['1023', '1077', '1078', '1079', '1081', '276', '277', '32766', '768', '769', '770']
# Not setting metadata
# 120 matching events found
# Setting baseline interval to [-0.2, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 120 events and 176 original time points ...
# 0 bad epochs dropped
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.9e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.9e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.9e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.9e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.9e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.9e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.9e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.9e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-06 (2.2e-16 eps * 3 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-06 (2.2e-16 eps * 3 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Epoch 1/50
# 341/341 [==============================] - 2s 4ms/step - loss: 0.7357 - accuracy: 0.5430 - val_loss: 0.6662 - val_accuracy: 0.6364
# Epoch 2/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.6613 - accuracy: 0.5846 - val_loss: 0.6478 - val_accuracy: 0.5983
# Epoch 3/50
# 341/341 [==============================] - 1s 4ms/step - loss: 0.6430 - accuracy: 0.6159 - val_loss: 0.6321 - val_accuracy: 0.6479
# Epoch 4/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.6298 - accuracy: 0.6380 - val_loss: 0.6299 - val_accuracy: 0.6099
# Epoch 5/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.6147 - accuracy: 0.6601 - val_loss: 0.6201 - val_accuracy: 0.6413
# Epoch 6/50
# 341/341 [==============================] - 1s 4ms/step - loss: 0.6039 - accuracy: 0.6620 - val_loss: 0.5957 - val_accuracy: 0.6901
# Epoch 7/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.5930 - accuracy: 0.6765 - val_loss: 0.5915 - val_accuracy: 0.6860
# Epoch 8/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.5844 - accuracy: 0.6848 - val_loss: 0.5823 - val_accuracy: 0.6959
# Epoch 9/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.5749 - accuracy: 0.6967 - val_loss: 0.5736 - val_accuracy: 0.7157
# Epoch 10/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.5669 - accuracy: 0.7038 - val_loss: 0.5656 - val_accuracy: 0.7132
# Epoch 11/50
# 341/341 [==============================] - 1s 4ms/step - loss: 0.5594 - accuracy: 0.7131 - val_loss: 0.5565 - val_accuracy: 0.7273
# Epoch 12/50
# 341/341 [==============================] - 1s 4ms/step - loss: 0.5540 - accuracy: 0.7152 - val_loss: 0.5534 - val_accuracy: 0.7314
# Epoch 13/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.5459 - accuracy: 0.7188 - val_loss: 0.5418 - val_accuracy: 0.7455
# Epoch 14/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.5371 - accuracy: 0.7298 - val_loss: 0.5383 - val_accuracy: 0.7438
# Epoch 15/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.5343 - accuracy: 0.7280 - val_loss: 0.5333 - val_accuracy: 0.7488
# Epoch 16/50
# 341/341 [==============================] - 1s 4ms/step - loss: 0.5279 - accuracy: 0.7276 - val_loss: 0.5249 - val_accuracy: 0.7479
# Epoch 17/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.5236 - accuracy: 0.7289 - val_loss: 0.5268 - val_accuracy: 0.7215
# Epoch 18/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.5185 - accuracy: 0.7345 - val_loss: 0.5210 - val_accuracy: 0.7388
# Epoch 19/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.5140 - accuracy: 0.7294 - val_loss: 0.5180 - val_accuracy: 0.7372
# Epoch 20/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.5118 - accuracy: 0.7298 - val_loss: 0.5093 - val_accuracy: 0.7496
# Epoch 21/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.5070 - accuracy: 0.7356 - val_loss: 0.5075 - val_accuracy: 0.7421
# Epoch 22/50
# 341/341 [==============================] - 1s 4ms/step - loss: 0.5053 - accuracy: 0.7308 - val_loss: 0.5059 - val_accuracy: 0.7471
# Epoch 23/50
# 341/341 [==============================] - 1s 4ms/step - loss: 0.5021 - accuracy: 0.7323 - val_loss: 0.4968 - val_accuracy: 0.7545
# Epoch 24/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.4965 - accuracy: 0.7377 - val_loss: 0.5092 - val_accuracy: 0.7132
# Epoch 25/50
# 341/341 [==============================] - 1s 4ms/step - loss: 0.4959 - accuracy: 0.7331 - val_loss: 0.4982 - val_accuracy: 0.7380
# Epoch 26/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.4913 - accuracy: 0.7366 - val_loss: 0.4899 - val_accuracy: 0.7545
# Epoch 27/50
# 341/341 [==============================] - 1s 4ms/step - loss: 0.4882 - accuracy: 0.7372 - val_loss: 0.4891 - val_accuracy: 0.7570
# Epoch 28/50
# 341/341 [==============================] - 1s 4ms/step - loss: 0.4868 - accuracy: 0.7319 - val_loss: 0.4895 - val_accuracy: 0.7529
# Epoch 29/50
# 341/341 [==============================] - 1s 4ms/step - loss: 0.4840 - accuracy: 0.7396 - val_loss: 0.4796 - val_accuracy: 0.7562
# Epoch 30/50
# 341/341 [==============================] - 1s 4ms/step - loss: 0.4824 - accuracy: 0.7418 - val_loss: 0.4774 - val_accuracy: 0.7529
# Epoch 31/50
# 341/341 [==============================] - 1s 4ms/step - loss: 0.4768 - accuracy: 0.7474 - val_loss: 0.4703 - val_accuracy: 0.7636
# Epoch 32/50
# 341/341 [==============================] - 1s 4ms/step - loss: 0.4734 - accuracy: 0.7492 - val_loss: 0.4866 - val_accuracy: 0.7331
# Epoch 33/50
# 341/341 [==============================] - 1s 4ms/step - loss: 0.4676 - accuracy: 0.7511 - val_loss: 0.4717 - val_accuracy: 0.7620
# Epoch 34/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.4670 - accuracy: 0.7545 - val_loss: 0.5070 - val_accuracy: 0.7322
# Epoch 35/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.4644 - accuracy: 0.7523 - val_loss: 0.4608 - val_accuracy: 0.7719
# Epoch 36/50
# 341/341 [==============================] - 1s 4ms/step - loss: 0.4591 - accuracy: 0.7607 - val_loss: 0.4549 - val_accuracy: 0.7669
# Epoch 37/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.4573 - accuracy: 0.7622 - val_loss: 0.4503 - val_accuracy: 0.7835
# Epoch 38/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.4537 - accuracy: 0.7639 - val_loss: 0.4570 - val_accuracy: 0.7711
# Epoch 39/50
# 341/341 [==============================] - 1s 4ms/step - loss: 0.4502 - accuracy: 0.7649 - val_loss: 0.4539 - val_accuracy: 0.7744
# Epoch 40/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.4490 - accuracy: 0.7716 - val_loss: 0.4481 - val_accuracy: 0.7711
# Epoch 41/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.4449 - accuracy: 0.7706 - val_loss: 0.4378 - val_accuracy: 0.7893
# Epoch 42/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.4411 - accuracy: 0.7728 - val_loss: 0.4353 - val_accuracy: 0.7983
# Epoch 43/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.4404 - accuracy: 0.7722 - val_loss: 0.4372 - val_accuracy: 0.7802
# Epoch 44/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.4381 - accuracy: 0.7745 - val_loss: 0.4389 - val_accuracy: 0.7793
# Epoch 45/50
# 341/341 [==============================] - 1s 4ms/step - loss: 0.4315 - accuracy: 0.7822 - val_loss: 0.4369 - val_accuracy: 0.7760
# Epoch 46/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.4286 - accuracy: 0.7839 - val_loss: 0.4408 - val_accuracy: 0.7942
# Epoch 47/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.4285 - accuracy: 0.7790 - val_loss: 0.4203 - val_accuracy: 0.8074
# Epoch 48/50
# 341/341 [==============================] - 1s 4ms/step - loss: 0.4244 - accuracy: 0.7844 - val_loss: 0.4128 - val_accuracy: 0.8050
# Epoch 49/50
# 341/341 [==============================] - 1s 3ms/step - loss: 0.4250 - accuracy: 0.7834 - val_loss: 0.4168 - val_accuracy: 0.8041
# Epoch 50/50
# 341/341 [==============================] - 1s 4ms/step - loss: 0.4179 - accuracy: 0.7904 - val_loss: 0.4222 - val_accuracy: 0.7818
# 162/162 [==============================] - 0s 2ms/step - loss: 0.4229 - accuracy: 0.7749
# 162/162 [==============================] - 0s 2ms/step
# Test accuracy: 0.7748842592592593
# Cohen's Kappa score: 0.5500795167949108
