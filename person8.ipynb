# %%
import numpy as np
import mne
from mne.decoding import CSP
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import confusion_matrix, accuracy_score, cohen_kappa_score
import matplotlib.pyplot as plt
import seaborn as sns


# Function to preprocess data and extract specific events
def preprocess_data(file_path, event_ids):
    raw = mne.io.read_raw_gdf(file_path, preload=True)
    raw.set_eeg_reference()

    # Select EEG channels and create epochs
    desired_channels = ['EEG:C3', 'EEG:Cz', 'EEG:C4']
    raw.pick_channels(desired_channels)
    events, _ = mne.events_from_annotations(raw)
    epochs = mne.Epochs(raw, events, event_id=event_ids, on_missing='warn')
    labels = epochs.events[:, -1]
    data = epochs.get_data()

    return data, labels

# File paths and corresponding event IDs
file_paths = ["Person8\B0801T.gdf", "Person8\B0802T.gdf"]
event_ids_list = [{'T0': 10, 'T1': 11}, {'T0': 10, 'T1': 11}]

# Lists to store preprocessed data and labels
all_data = []
all_labels = []

# Preprocess data from each file and extract specific events
for file_path, event_ids in zip(file_paths, event_ids_list):
    data, labels = preprocess_data(file_path, event_ids)
    all_data.append(data)
    all_labels.append(labels)

# Concatenate the data and labels arrays from all files
merged_data = np.concatenate(all_data, axis=0)
merged_labels = np.concatenate(all_labels, axis=0)

# Parameters
n_channels = merged_data.shape[1]
window_size = 200
step_size = 5

# Frequency bands
frequency_bands = [(2, 6), (6, 10), (10, 14), (14, 18),
                   (18, 22), (22, 26), (26, 30), (30, 34)]

# Extract CSP features for each frequency band
X_band = []  # List to store features
y_band = []  # List to store labels

for band_idx, (fmin, fmax) in enumerate(frequency_bands):
    for t_start in range(0, merged_data.shape[0] - window_size + 1, step_size):
        t_end = t_start + window_size
        X_window = merged_data[:, :, t_start:t_end]
        y_window = merged_labels

        csp = CSP(n_components=10, transform_into='average_power')
        csp.fit(X_window, y_window)
        X_band.append(csp.transform(X_window))
        y_band.extend(y_window)

# Convert lists to numpy arrays
X_band = np.concatenate(X_band, axis=0)
y_band = np.array(y_band)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_band, y_band, test_size=0.4, random_state=42)

input_shape = (3,1)

model = keras.Sequential()
model.add(layers.Reshape((3, 1), input_shape=input_shape))  # Reshape the input to (3, 1) for 1D convolution
model.add(layers.Conv1D(16, kernel_size=3, activation='relu', padding='same'))
model.add(layers.MaxPooling1D(pool_size=2))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(4, activation='softmax'))  # Adjust units to match the number of classes

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

y_train_processed = y_train - 10  # Map 10 to 0 and 11 to 1
y_test_processed = y_test - 10

history = model.fit(X_train, y_train_processed, epochs=250, batch_size=32, validation_split=0.1)

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test_processed)

# Predict labels for the test set
predicted_labels = model.predict(X_test)
predicted_labels = np.argmax(predicted_labels, axis=1)

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test_processed, predicted_labels)

# Calculate overall accuracy
accuracy = accuracy_score(y_test_processed, predicted_labels)

# Calculate Cohen's Kappa score
kappa = cohen_kappa_score(y_test_processed, predicted_labels)

# Print accuracy and kappa score
print(f"Test accuracy: {accuracy}")
print(f"Cohen's Kappa score: {kappa}")

# Plot confusion matrix
plt.figure(figsize=(5, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Left ', 'Right'], yticklabels=['Left', 'Right'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# Extracting EDF parameters from c:\Users\HP\Desktop\session2\Person8\B0801T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 787728  =      0.000 ...  3150.912 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13652\980875204.py:14: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path, preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Used Annotations descriptions: ['1023', '1077', '1078', '1079', '1081', '276', '277', '32766', '768', '769', '770']
# Not setting metadata
# 160 matching events found
# Setting baseline interval to [-0.2, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 160 events and 176 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from c:\Users\HP\Desktop\session2\Person8\B0802T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13652\980875204.py:14: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path, preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Used Annotations descriptions: ['1023', '1077', '1078', '1079', '1081', '276', '277', '32766', '768', '769', '770']
# Not setting metadata
# 120 matching events found
# Setting baseline interval to [-0.2, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 120 events and 176 original time points ...
# 0 bad epochs dropped
# Computing rank from data with rank=None
#     Using tolerance 9.1e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1e-06 (2.2e-16 eps * 3 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.9e-07 (2.2e-16 eps * 3 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.9e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.8e-07 (2.2e-16 eps * 3 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.9e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.7e-07 (2.2e-16 eps * 3 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.8e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.6e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.7e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.6e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.7e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.6e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.5e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.3e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.4e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.2e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.3e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.2e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.2e-07 (2.2e-16 eps * 3 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.1e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.1e-07 (2.2e-16 eps * 3 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8e-07 (2.2e-16 eps * 3 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.8e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.9e-07 (2.2e-16 eps * 3 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.7e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.8e-07 (2.2e-16 eps * 3 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.6e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.6e-07 (2.2e-16 eps * 3 dim * 1.1e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.4e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.1e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1e-06 (2.2e-16 eps * 3 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.9e-07 (2.2e-16 eps * 3 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.9e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.8e-07 (2.2e-16 eps * 3 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.9e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.7e-07 (2.2e-16 eps * 3 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.8e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.6e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.7e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.6e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.7e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.6e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.5e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.3e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.4e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.2e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.3e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.2e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.2e-07 (2.2e-16 eps * 3 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.1e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.1e-07 (2.2e-16 eps * 3 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8e-07 (2.2e-16 eps * 3 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.8e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.9e-07 (2.2e-16 eps * 3 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.7e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.8e-07 (2.2e-16 eps * 3 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.6e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.6e-07 (2.2e-16 eps * 3 dim * 1.1e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.4e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.1e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1e-06 (2.2e-16 eps * 3 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.9e-07 (2.2e-16 eps * 3 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.9e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.8e-07 (2.2e-16 eps * 3 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.9e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.7e-07 (2.2e-16 eps * 3 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.8e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.6e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.7e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.6e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.7e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.6e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.5e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.3e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.4e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.2e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.3e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.2e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.2e-07 (2.2e-16 eps * 3 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.1e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.1e-07 (2.2e-16 eps * 3 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8e-07 (2.2e-16 eps * 3 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.8e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.9e-07 (2.2e-16 eps * 3 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.7e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.8e-07 (2.2e-16 eps * 3 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.6e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.6e-07 (2.2e-16 eps * 3 dim * 1.1e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.4e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.1e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1e-06 (2.2e-16 eps * 3 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.9e-07 (2.2e-16 eps * 3 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.9e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.8e-07 (2.2e-16 eps * 3 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.9e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.7e-07 (2.2e-16 eps * 3 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.8e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.6e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.7e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.6e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.7e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.6e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.5e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.3e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.4e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.2e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.3e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.2e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.2e-07 (2.2e-16 eps * 3 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.1e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.1e-07 (2.2e-16 eps * 3 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8e-07 (2.2e-16 eps * 3 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.8e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.9e-07 (2.2e-16 eps * 3 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.7e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.8e-07 (2.2e-16 eps * 3 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.6e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.6e-07 (2.2e-16 eps * 3 dim * 1.1e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.4e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.1e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1e-06 (2.2e-16 eps * 3 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.9e-07 (2.2e-16 eps * 3 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.9e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.8e-07 (2.2e-16 eps * 3 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.9e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.7e-07 (2.2e-16 eps * 3 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.8e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.6e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.7e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.6e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.7e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.6e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.5e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.3e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.4e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.2e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.3e-07 (2.2e-16 eps * 3 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.2e-07 (2.2e-16 eps * 3 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.2e-07 (2.2e-16 eps * 3 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
# ...
# Epoch 143/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4263 - accuracy: 0.7821 - val_loss: 0.4283 - val_accuracy: 0.7694
# Epoch 144/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4265 - accuracy: 0.7807 - val_loss: 0.4141 - val_accuracy: 0.8026
# Epoch 145/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4244 - accuracy: 0.7808 - val_loss: 0.4182 - val_accuracy: 0.7908
# Epoch 146/250
# 643/643 [==============================] - 4s 7ms/step - loss: 0.4244 - accuracy: 0.7815 - val_loss: 0.4296 - val_accuracy: 0.7904
# Epoch 147/250
# 643/643 [==============================] - 5s 8ms/step - loss: 0.4237 - accuracy: 0.7819 - val_loss: 0.4246 - val_accuracy: 0.7939
# Epoch 148/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4233 - accuracy: 0.7822 - val_loss: 0.4362 - val_accuracy: 0.7882
# Epoch 149/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4245 - accuracy: 0.7816 - val_loss: 0.4110 - val_accuracy: 0.7956
# Epoch 150/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4207 - accuracy: 0.7861 - val_loss: 0.4149 - val_accuracy: 0.7939
# Epoch 151/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4205 - accuracy: 0.7850 - val_loss: 0.4205 - val_accuracy: 0.7807
# Epoch 152/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4221 - accuracy: 0.7822 - val_loss: 0.4272 - val_accuracy: 0.7746
# Epoch 153/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4216 - accuracy: 0.7844 - val_loss: 0.4201 - val_accuracy: 0.7934
# Epoch 154/250
# 643/643 [==============================] - 5s 7ms/step - loss: 0.4194 - accuracy: 0.7868 - val_loss: 0.4201 - val_accuracy: 0.8026
# Epoch 155/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4204 - accuracy: 0.7823 - val_loss: 0.4138 - val_accuracy: 0.7921
# Epoch 156/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4207 - accuracy: 0.7859 - val_loss: 0.4120 - val_accuracy: 0.8070
# Epoch 157/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4206 - accuracy: 0.7874 - val_loss: 0.4214 - val_accuracy: 0.7991
# Epoch 158/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4179 - accuracy: 0.7884 - val_loss: 0.4343 - val_accuracy: 0.7812
# Epoch 159/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4195 - accuracy: 0.7857 - val_loss: 0.4179 - val_accuracy: 0.7921
# Epoch 160/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4169 - accuracy: 0.7913 - val_loss: 0.4223 - val_accuracy: 0.7926
# Epoch 161/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4166 - accuracy: 0.7890 - val_loss: 0.4170 - val_accuracy: 0.7952
# Epoch 162/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4194 - accuracy: 0.7848 - val_loss: 0.4246 - val_accuracy: 0.7856
# Epoch 163/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4180 - accuracy: 0.7856 - val_loss: 0.4197 - val_accuracy: 0.7926
# Epoch 164/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4161 - accuracy: 0.7896 - val_loss: 0.4110 - val_accuracy: 0.7939
# Epoch 165/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4173 - accuracy: 0.7866 - val_loss: 0.4141 - val_accuracy: 0.8000
# Epoch 166/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4150 - accuracy: 0.7891 - val_loss: 0.4203 - val_accuracy: 0.7996
# Epoch 167/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4173 - accuracy: 0.7902 - val_loss: 0.4164 - val_accuracy: 0.7860
# Epoch 168/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4152 - accuracy: 0.7905 - val_loss: 0.4256 - val_accuracy: 0.7755
# Epoch 169/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4160 - accuracy: 0.7898 - val_loss: 0.4094 - val_accuracy: 0.8035
# Epoch 170/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4154 - accuracy: 0.7887 - val_loss: 0.4117 - val_accuracy: 0.7847
# Epoch 171/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4143 - accuracy: 0.7920 - val_loss: 0.4257 - val_accuracy: 0.7781
# Epoch 172/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4137 - accuracy: 0.7915 - val_loss: 0.4159 - val_accuracy: 0.7974
# Epoch 173/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4159 - accuracy: 0.7889 - val_loss: 0.4094 - val_accuracy: 0.7934
# Epoch 174/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4123 - accuracy: 0.7944 - val_loss: 0.4136 - val_accuracy: 0.7978
# Epoch 175/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4114 - accuracy: 0.7937 - val_loss: 0.4044 - val_accuracy: 0.8004
# Epoch 176/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4131 - accuracy: 0.7904 - val_loss: 0.4128 - val_accuracy: 0.7956
# Epoch 177/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4129 - accuracy: 0.7896 - val_loss: 0.4187 - val_accuracy: 0.7939
# Epoch 178/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4125 - accuracy: 0.7913 - val_loss: 0.4431 - val_accuracy: 0.7834
# Epoch 179/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4110 - accuracy: 0.7944 - val_loss: 0.4193 - val_accuracy: 0.7952
# Epoch 180/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4085 - accuracy: 0.7940 - val_loss: 0.4108 - val_accuracy: 0.7965
# Epoch 181/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4114 - accuracy: 0.7932 - val_loss: 0.4029 - val_accuracy: 0.8031
# Epoch 182/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4103 - accuracy: 0.7936 - val_loss: 0.4108 - val_accuracy: 0.7987
# Epoch 183/250
# 643/643 [==============================] - 4s 7ms/step - loss: 0.4116 - accuracy: 0.7931 - val_loss: 0.4136 - val_accuracy: 0.7917
# Epoch 184/250
# 643/643 [==============================] - 4s 7ms/step - loss: 0.4106 - accuracy: 0.7921 - val_loss: 0.4188 - val_accuracy: 0.7987
# Epoch 185/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4136 - accuracy: 0.7909 - val_loss: 0.4062 - val_accuracy: 0.8035
# Epoch 186/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4097 - accuracy: 0.7936 - val_loss: 0.4095 - val_accuracy: 0.7974
# Epoch 187/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4099 - accuracy: 0.7958 - val_loss: 0.4001 - val_accuracy: 0.7943
# Epoch 188/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4102 - accuracy: 0.7914 - val_loss: 0.4093 - val_accuracy: 0.7987
# Epoch 189/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4095 - accuracy: 0.7951 - val_loss: 0.4138 - val_accuracy: 0.7930
# Epoch 190/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4082 - accuracy: 0.7917 - val_loss: 0.4036 - val_accuracy: 0.8031
# Epoch 191/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4097 - accuracy: 0.7935 - val_loss: 0.4125 - val_accuracy: 0.7943
# Epoch 192/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4062 - accuracy: 0.7944 - val_loss: 0.4234 - val_accuracy: 0.7873
# Epoch 193/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4073 - accuracy: 0.7962 - val_loss: 0.4056 - val_accuracy: 0.7965
# Epoch 194/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4089 - accuracy: 0.7952 - val_loss: 0.4109 - val_accuracy: 0.7943
# Epoch 195/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4069 - accuracy: 0.7928 - val_loss: 0.4127 - val_accuracy: 0.7904
# Epoch 196/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4063 - accuracy: 0.7938 - val_loss: 0.4533 - val_accuracy: 0.7912
# Epoch 197/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4102 - accuracy: 0.7915 - val_loss: 0.4041 - val_accuracy: 0.8044
# Epoch 198/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4074 - accuracy: 0.7939 - val_loss: 0.4088 - val_accuracy: 0.7991
# Epoch 199/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.4062 - accuracy: 0.7948 - val_loss: 0.4006 - val_accuracy: 0.7969
# Epoch 200/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4062 - accuracy: 0.7947 - val_loss: 0.4004 - val_accuracy: 0.7982
# Epoch 201/250
# 643/643 [==============================] - 3s 4ms/step - loss: 0.4066 - accuracy: 0.7926 - val_loss: 0.4079 - val_accuracy: 0.7965
# Epoch 202/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4078 - accuracy: 0.7939 - val_loss: 0.4133 - val_accuracy: 0.7899
# Epoch 203/250
# 643/643 [==============================] - 3s 4ms/step - loss: 0.4055 - accuracy: 0.7953 - val_loss: 0.4042 - val_accuracy: 0.7978
# Epoch 204/250
# 643/643 [==============================] - 3s 4ms/step - loss: 0.4035 - accuracy: 0.7978 - val_loss: 0.4211 - val_accuracy: 0.7899
# Epoch 205/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4053 - accuracy: 0.7958 - val_loss: 0.4181 - val_accuracy: 0.7939
# Epoch 206/250
# 643/643 [==============================] - 3s 4ms/step - loss: 0.4027 - accuracy: 0.7974 - val_loss: 0.4050 - val_accuracy: 0.8000
# Epoch 207/250
# 643/643 [==============================] - 3s 4ms/step - loss: 0.4063 - accuracy: 0.7963 - val_loss: 0.3994 - val_accuracy: 0.8031
# Epoch 208/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4034 - accuracy: 0.7968 - val_loss: 0.4079 - val_accuracy: 0.7974
# Epoch 209/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4014 - accuracy: 0.8008 - val_loss: 0.4552 - val_accuracy: 0.7654
# Epoch 210/250
# 643/643 [==============================] - 3s 4ms/step - loss: 0.4044 - accuracy: 0.7955 - val_loss: 0.3968 - val_accuracy: 0.8044
# Epoch 211/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4027 - accuracy: 0.7997 - val_loss: 0.4030 - val_accuracy: 0.7982
# Epoch 212/250
# 643/643 [==============================] - 3s 4ms/step - loss: 0.4038 - accuracy: 0.7960 - val_loss: 0.4136 - val_accuracy: 0.7877
# Epoch 213/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4026 - accuracy: 0.7993 - val_loss: 0.4197 - val_accuracy: 0.7873
# Epoch 214/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4034 - accuracy: 0.7973 - val_loss: 0.4038 - val_accuracy: 0.8048
# Epoch 215/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4010 - accuracy: 0.7985 - val_loss: 0.4226 - val_accuracy: 0.7829
# Epoch 216/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4047 - accuracy: 0.7989 - val_loss: 0.4002 - val_accuracy: 0.8022
# Epoch 217/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4023 - accuracy: 0.7995 - val_loss: 0.4057 - val_accuracy: 0.7952
# Epoch 218/250
# 643/643 [==============================] - 3s 4ms/step - loss: 0.4001 - accuracy: 0.8018 - val_loss: 0.4077 - val_accuracy: 0.7978
# Epoch 219/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.3998 - accuracy: 0.8001 - val_loss: 0.4115 - val_accuracy: 0.7895
# Epoch 220/250
# 643/643 [==============================] - 3s 4ms/step - loss: 0.4020 - accuracy: 0.7967 - val_loss: 0.4122 - val_accuracy: 0.7917
# Epoch 221/250
# 643/643 [==============================] - 3s 4ms/step - loss: 0.4037 - accuracy: 0.7949 - val_loss: 0.4006 - val_accuracy: 0.8018
# Epoch 222/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4012 - accuracy: 0.7982 - val_loss: 0.4193 - val_accuracy: 0.7912
# Epoch 223/250
# 643/643 [==============================] - 3s 4ms/step - loss: 0.3994 - accuracy: 0.8008 - val_loss: 0.4070 - val_accuracy: 0.7899
# Epoch 224/250
# 643/643 [==============================] - 3s 4ms/step - loss: 0.4000 - accuracy: 0.7998 - val_loss: 0.3996 - val_accuracy: 0.8035
# Epoch 225/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4003 - accuracy: 0.8009 - val_loss: 0.4051 - val_accuracy: 0.7996
# Epoch 226/250
# 643/643 [==============================] - 3s 4ms/step - loss: 0.3988 - accuracy: 0.8012 - val_loss: 0.3994 - val_accuracy: 0.8022
# Epoch 227/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.4010 - accuracy: 0.7991 - val_loss: 0.4179 - val_accuracy: 0.7904
# Epoch 228/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.3998 - accuracy: 0.7993 - val_loss: 0.3988 - val_accuracy: 0.8105
# Epoch 229/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.3983 - accuracy: 0.8031 - val_loss: 0.4026 - val_accuracy: 0.8035
# Epoch 230/250
# 643/643 [==============================] - 3s 4ms/step - loss: 0.3984 - accuracy: 0.8005 - val_loss: 0.4000 - val_accuracy: 0.8031
# Epoch 231/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.3984 - accuracy: 0.8016 - val_loss: 0.4124 - val_accuracy: 0.7877
# Epoch 232/250
# 643/643 [==============================] - 3s 4ms/step - loss: 0.3998 - accuracy: 0.7984 - val_loss: 0.4052 - val_accuracy: 0.8000
# Epoch 233/250
# 643/643 [==============================] - 3s 4ms/step - loss: 0.3985 - accuracy: 0.8016 - val_loss: 0.4060 - val_accuracy: 0.7969
# Epoch 234/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.3997 - accuracy: 0.8007 - val_loss: 0.4030 - val_accuracy: 0.7978
# Epoch 235/250
# 643/643 [==============================] - 3s 4ms/step - loss: 0.3975 - accuracy: 0.7984 - val_loss: 0.4059 - val_accuracy: 0.7926
# Epoch 236/250
# 643/643 [==============================] - 3s 4ms/step - loss: 0.3966 - accuracy: 0.8026 - val_loss: 0.3947 - val_accuracy: 0.7978
# Epoch 237/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.3979 - accuracy: 0.8011 - val_loss: 0.4069 - val_accuracy: 0.8000
# Epoch 238/250
# 643/643 [==============================] - 3s 4ms/step - loss: 0.3958 - accuracy: 0.8029 - val_loss: 0.4132 - val_accuracy: 0.7891
# Epoch 239/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.3971 - accuracy: 0.8028 - val_loss: 0.4008 - val_accuracy: 0.7978
# Epoch 240/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.3987 - accuracy: 0.8047 - val_loss: 0.4020 - val_accuracy: 0.8013
# Epoch 241/250
# 643/643 [==============================] - 3s 4ms/step - loss: 0.3983 - accuracy: 0.8015 - val_loss: 0.3970 - val_accuracy: 0.7974
# Epoch 242/250
# 643/643 [==============================] - 3s 4ms/step - loss: 0.3961 - accuracy: 0.8072 - val_loss: 0.4055 - val_accuracy: 0.7956
# Epoch 243/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.3938 - accuracy: 0.8055 - val_loss: 0.4115 - val_accuracy: 0.7943
# Epoch 244/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.3947 - accuracy: 0.8050 - val_loss: 0.3912 - val_accuracy: 0.8074
# Epoch 245/250
# 643/643 [==============================] - 3s 4ms/step - loss: 0.3950 - accuracy: 0.8041 - val_loss: 0.3988 - val_accuracy: 0.8088
# Epoch 246/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.3945 - accuracy: 0.8046 - val_loss: 0.3951 - val_accuracy: 0.8035
# Epoch 247/250
# 643/643 [==============================] - 3s 5ms/step - loss: 0.3949 - accuracy: 0.8038 - val_loss: 0.3932 - val_accuracy: 0.8079
# Epoch 248/250
# 643/643 [==============================] - 3s 4ms/step - loss: 0.3949 - accuracy: 0.8020 - val_loss: 0.4017 - val_accuracy: 0.7969
# Epoch 249/250
# 643/643 [==============================] - 4s 6ms/step - loss: 0.3945 - accuracy: 0.8048 - val_loss: 0.4012 - val_accuracy: 0.8053
# Epoch 250/250
# 643/643 [==============================] - 3s 4ms/step - loss: 0.3931 - accuracy: 0.8031 - val_loss: 0.3978 - val_accuracy: 0.8026
# 476/476 [==============================] - 2s 3ms/step - loss: 0.4100 - accuracy: 0.7902
# 476/476 [==============================] - 2s 3ms/step
# Test accuracy: 0.7901785714285714
# Cohen's Kappa score: 0.5806081339333775
