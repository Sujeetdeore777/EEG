# %%
import numpy as np
import mne
from mne.decoding import CSP
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import confusion_matrix, accuracy_score, cohen_kappa_score
import matplotlib.pyplot as plt
import seaborn as sns


# Function to preprocess data and extract specific events
def preprocess_data(file_path, event_ids):
    raw = mne.io.read_raw_gdf(file_path, preload=True)
    raw.set_eeg_reference()

    # Select EEG channels and create epochs
    desired_channels = ['EEG:C3', 'EEG:Cz', 'EEG:C4']
    raw.pick_channels(desired_channels)
    events, _ = mne.events_from_annotations(raw)
    epochs = mne.Epochs(raw, events, event_id=event_ids, on_missing='warn')
    labels = epochs.events[:, -1]
    data = epochs.get_data()

    return data, labels

# File paths and corresponding event IDs
file_paths = ["Person4\B0401T.gdf", "Person4\B0402T.gdf"]
event_ids_list = [{'T0': 10, 'T1': 11}, {'T0': 10, 'T1': 11}]

# Lists to store preprocessed data and labels
all_data = []
all_labels = []

# Preprocess data from each file and extract specific events
for file_path, event_ids in zip(file_paths, event_ids_list):
    data, labels = preprocess_data(file_path, event_ids)
    all_data.append(data)
    all_labels.append(labels)

# Concatenate the data and labels arrays from all files
merged_data = np.concatenate(all_data, axis=0)
merged_labels = np.concatenate(all_labels, axis=0)

# Parameters
n_channels = merged_data.shape[1]
window_size = 200
step_size = 5

# Frequency bands
frequency_bands = [(2, 6), (6, 10), (10, 14), (14, 18),
                   (18, 22), (22, 26), (26, 30), (30, 34)]

# Extract CSP features for each frequency band
X_band = []  # List to store features
y_band = []  # List to store labels

for band_idx, (fmin, fmax) in enumerate(frequency_bands):
    for t_start in range(0, merged_data.shape[0] - window_size + 1, step_size):
        t_end = t_start + window_size
        X_window = merged_data[:, :, t_start:t_end]
        y_window = merged_labels

        csp = CSP(n_components=10, transform_into='average_power')
        csp.fit(X_window, y_window)
        X_band.append(csp.transform(X_window))
        y_band.extend(y_window)

# Convert lists to numpy arrays
X_band = np.concatenate(X_band, axis=0)
y_band = np.array(y_band)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_band, y_band, test_size=0.4, random_state=42)

input_shape = (3,1)

model = keras.Sequential()
model.add(layers.Reshape((3, 1), input_shape=input_shape))  # Reshape the input to (3, 1) for 1D convolution
model.add(layers.Conv1D(16, kernel_size=3, activation='relu', padding='same'))
model.add(layers.MaxPooling1D(pool_size=2))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(4, activation='softmax'))  # Adjust units to match the number of classes

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

y_train_processed = y_train - 10  # Map 10 to 0 and 11 to 1
y_test_processed = y_test - 10

history = model.fit(X_train, y_train_processed, epochs=250, batch_size=32, validation_split=0.1)

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test_processed)

# Predict labels for the test set
predicted_labels = model.predict(X_test)
predicted_labels = np.argmax(predicted_labels, axis=1)

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test_processed, predicted_labels)

# Calculate overall accuracy
accuracy = accuracy_score(y_test_processed, predicted_labels)

# Calculate Cohen's Kappa score
kappa = cohen_kappa_score(y_test_processed, predicted_labels)

# Print accuracy and kappa score
print(f"Test accuracy: {accuracy}")
print(f"Cohen's Kappa score: {kappa}")

# Plot confusion matrix
plt.figure(figsize=(5, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Left ', 'Right'], yticklabels=['Left', 'Right'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# Extracting EDF parameters from c:\Users\HP\Desktop\session2\Person4\B0401T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_5716\1573332642.py:14: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path, preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Used Annotations descriptions: ['1023', '1077', '1078', '1079', '1081', '276', '277', '32766', '768', '769', '770']
# Not setting metadata
# 120 matching events found
# Setting baseline interval to [-0.2, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 120 events and 176 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from c:\Users\HP\Desktop\session2\Person4\B0402T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# Reading 0 ... 696265  =      0.000 ...  2785.060 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_5716\1573332642.py:14: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_gdf(file_path, preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Used Annotations descriptions: ['1023', '1077', '1078', '1079', '1081', '276', '277', '32766', '768', '769', '770']
# Not setting metadata
# 140 matching events found
# Setting baseline interval to [-0.2, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 140 events and 176 original time points ...
# 0 bad epochs dropped
# Computing rank from data with rank=None
#     Using tolerance 1.1e
250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4365 - accuracy: 0.7657 - val_loss: 0.4389 - val_accuracy: 0.7745
# Epoch 199/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4376 - accuracy: 0.7702 - val_loss: 0.4437 - val_accuracy: 0.7523
# Epoch 200/250
# 457/457 [==============================] - 1s 3ms/step - loss: 0.4337 - accuracy: 0.7712 - val_loss: 0.4351 - val_accuracy: 0.7726
# Epoch 201/250
# 457/457 [==============================] - 1s 3ms/step - loss: 0.4348 - accuracy: 0.7713 - val_loss: 0.4418 - val_accuracy: 0.7560
# Epoch 202/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4374 - accuracy: 0.7712 - val_loss: 0.4488 - val_accuracy: 0.7603
# Epoch 203/250
# 457/457 [==============================] - 1s 3ms/step - loss: 0.4364 - accuracy: 0.7673 - val_loss: 0.4341 - val_accuracy: 0.7708
# Epoch 204/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4360 - accuracy: 0.7724 - val_loss: 0.4576 - val_accuracy: 0.7418
# Epoch 205/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4345 - accuracy: 0.7744 - val_loss: 0.4382 - val_accuracy: 0.7572
# Epoch 206/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4345 - accuracy: 0.7725 - val_loss: 0.4398 - val_accuracy: 0.7739
# Epoch 207/250
# 457/457 [==============================] - 1s 3ms/step - loss: 0.4343 - accuracy: 0.7726 - val_loss: 0.4281 - val_accuracy: 0.7800
# Epoch 208/250
# 457/457 [==============================] - 2s 3ms/step - loss: 0.4343 - accuracy: 0.7708 - val_loss: 0.4359 - val_accuracy: 0.7640
# Epoch 209/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4327 - accuracy: 0.7703 - val_loss: 0.4373 - val_accuracy: 0.7714
# Epoch 210/250
# 457/457 [==============================] - 2s 3ms/step - loss: 0.4323 - accuracy: 0.7705 - val_loss: 0.4492 - val_accuracy: 0.7616
# Epoch 211/250
# 457/457 [==============================] - 1s 3ms/step - loss: 0.4343 - accuracy: 0.7708 - val_loss: 0.4450 - val_accuracy: 0.7652
# Epoch 212/250
# 457/457 [==============================] - 2s 3ms/step - loss: 0.4350 - accuracy: 0.7717 - val_loss: 0.4297 - val_accuracy: 0.7825
# Epoch 213/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4333 - accuracy: 0.7713 - val_loss: 0.4324 - val_accuracy: 0.7720
# Epoch 214/250
# 457/457 [==============================] - 1s 3ms/step - loss: 0.4343 - accuracy: 0.7719 - val_loss: 0.4405 - val_accuracy: 0.7566
# Epoch 215/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4303 - accuracy: 0.7753 - val_loss: 0.4519 - val_accuracy: 0.7542
# Epoch 216/250
# 457/457 [==============================] - 2s 3ms/step - loss: 0.4305 - accuracy: 0.7729 - val_loss: 0.4373 - val_accuracy: 0.7683
# Epoch 217/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4311 - accuracy: 0.7714 - val_loss: 0.4272 - val_accuracy: 0.7794
# Epoch 218/250
# 457/457 [==============================] - 1s 3ms/step - loss: 0.4296 - accuracy: 0.7741 - val_loss: 0.4332 - val_accuracy: 0.7609
# Epoch 219/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4318 - accuracy: 0.7731 - val_loss: 0.4312 - val_accuracy: 0.7837
# Epoch 220/250
# 457/457 [==============================] - 2s 3ms/step - loss: 0.4315 - accuracy: 0.7723 - val_loss: 0.4743 - val_accuracy: 0.7252
# Epoch 221/250
# 457/457 [==============================] - 1s 3ms/step - loss: 0.4315 - accuracy: 0.7719 - val_loss: 0.4481 - val_accuracy: 0.7634
# Epoch 222/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4312 - accuracy: 0.7725 - val_loss: 0.4409 - val_accuracy: 0.7646
# Epoch 223/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4281 - accuracy: 0.7755 - val_loss: 0.4375 - val_accuracy: 0.7628
# Epoch 224/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4314 - accuracy: 0.7713 - val_loss: 0.4610 - val_accuracy: 0.7572
# Epoch 225/250
# 457/457 [==============================] - 1s 3ms/step - loss: 0.4306 - accuracy: 0.7751 - val_loss: 0.4336 - val_accuracy: 0.7733
# Epoch 226/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4279 - accuracy: 0.7769 - val_loss: 0.4303 - val_accuracy: 0.7843
# Epoch 227/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4295 - accuracy: 0.7752 - val_loss: 0.4319 - val_accuracy: 0.7751
# Epoch 228/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4272 - accuracy: 0.7784 - val_loss: 0.4341 - val_accuracy: 0.7776
# Epoch 229/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4285 - accuracy: 0.7774 - val_loss: 0.4336 - val_accuracy: 0.7634
# Epoch 230/250
# 457/457 [==============================] - 1s 3ms/step - loss: 0.4273 - accuracy: 0.7760 - val_loss: 0.4318 - val_accuracy: 0.7837
# Epoch 231/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4259 - accuracy: 0.7784 - val_loss: 0.4321 - val_accuracy: 0.7763
# Epoch 232/250
# 457/457 [==============================] - 2s 3ms/step - loss: 0.4274 - accuracy: 0.7739 - val_loss: 0.4230 - val_accuracy: 0.7874
# Epoch 233/250
# 457/457 [==============================] - 1s 3ms/step - loss: 0.4269 - accuracy: 0.7761 - val_loss: 0.4424 - val_accuracy: 0.7560
# Epoch 234/250
# 457/457 [==============================] - 1s 3ms/step - loss: 0.4253 - accuracy: 0.7768 - val_loss: 0.4420 - val_accuracy: 0.7622
# Epoch 235/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4260 - accuracy: 0.7746 - val_loss: 0.4211 - val_accuracy: 0.7843
# Epoch 236/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4245 - accuracy: 0.7795 - val_loss: 0.4394 - val_accuracy: 0.7560
# Epoch 237/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4254 - accuracy: 0.7806 - val_loss: 0.4397 - val_accuracy: 0.7726
# Epoch 238/250
# 457/457 [==============================] - 1s 3ms/step - loss: 0.4256 - accuracy: 0.7766 - val_loss: 0.4320 - val_accuracy: 0.7770
# Epoch 239/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4247 - accuracy: 0.7785 - val_loss: 0.4323 - val_accuracy: 0.7757
# Epoch 240/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4234 - accuracy: 0.7798 - val_loss: 0.4474 - val_accuracy: 0.7634
# Epoch 241/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4230 - accuracy: 0.7823 - val_loss: 0.4218 - val_accuracy: 0.7917
# Epoch 242/250
# 457/457 [==============================] - 1s 3ms/step - loss: 0.4251 - accuracy: 0.7783 - val_loss: 0.4437 - val_accuracy: 0.7640
# Epoch 243/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4225 - accuracy: 0.7801 - val_loss: 0.4305 - val_accuracy: 0.7800
# Epoch 244/250
# 457/457 [==============================] - 2s 3ms/step - loss: 0.4248 - accuracy: 0.7797 - val_loss: 0.4256 - val_accuracy: 0.7887
# Epoch 245/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4227 - accuracy: 0.7780 - val_loss: 0.4317 - val_accuracy: 0.7659
# Epoch 246/250
# 457/457 [==============================] - 1s 3ms/step - loss: 0.4224 - accuracy: 0.7801 - val_loss: 0.4253 - val_accuracy: 0.7751
# Epoch 247/250
# 457/457 [==============================] - 2s 4ms/step - loss: 0.4235 - accuracy: 0.7790 - val_loss: 0.4527 - val_accuracy: 0.7455
# Epoch 248/250
# 457/457 [==============================] - 2s 3ms/step - loss: 0.4223 - accuracy: 0.7780 - val_loss: 0.4287 - val_accuracy: 0.7708
# Epoch 249/250
# 457/457 [==============================] - 2s 3ms/step - loss: 0.4260 - accuracy: 0.7790 - val_loss: 0.4210 - val_accuracy: 0.7770
# Epoch 250/250
# 457/457 [==============================] - 1s 3ms/step - loss: 0.4217 - accuracy: 0.7815 - val_loss: 0.4176 - val_accuracy: 0.7843
# 338/338 [==============================] - 1s 3ms/step - loss: 0.4184 - accuracy: 0.7803
# 338/338 [==============================] - 1s 2ms/step
# Test accuracy: 0.7803254437869822
# Cohen's Kappa score: 0.5604155123478642
